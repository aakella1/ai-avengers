# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)
final_answer
# Out:
# 'Quantum computers use quantum bits (qubits) that can exist in multiple states simultaneously, unlike classical bits that are strictly either 0 or 1.'

# %%
#Make an initial list of messages to start the conversation with Claude
messages = []

# run the chat in a loop to have a conversation with Claude
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    # Call Claude with the 'chat' function
    answer = chat(messages)

    # Add Claude's response to the conversation history
    add_assistant_message(messages, answer)

    #print generated response
    print("-----")
    print(answer)
    print("-----")
# Out:
# > what is quantum computing
# -----
# # Quantum Computing
#
# Quantum computing is a revolutionary type of computing that uses the principles of **quantum mechanics** to process information in fundamentally different ways than classical computers.
#
# ## Key Differences from Classical Computing
#
# **Classical computers** use bits (0s and 1s) and process information sequentially.
#
# **Quantum computers** use:
#
# ### 1. **Qubits** (Quantum bits)
# - Can exist in multiple states simultaneously (both 0 and 1 at once)
# - This is called **superposition**
#
# ### 2. **Entanglement**
# - Qubits can be interconnected so that the state of one instantly affects others
# - Allows for complex correlations impossible in classical systems
#
# ### 3. **Interference**
# - Quantum states can amplify correct answers and cancel out wrong ones
#
# ## What They're Good At
#
# Quantum computers excel at specific problems:
# - **Cryptography** - breaking encryption or creating unbreakable codes
# - **Drug discovery** - simulating molecular interactions
# - **Optimization** - finding best solutions among countless possibilities
# - **Artificial intelligence** - certain machine learning tasks
# - **Financial modeling** - complex risk analysis
#
# ## Current Status
#
# Quantum computing is still **experimental**. Challenges include:
# - Qubits are extremely fragile
# - Require near absolute-zero temperatures
# - High error rates
# - Very expensive
#
# Companies like IBM, Google, and others are making progress, but practical, large-scale quantum computers are likely still years away.
# -----
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 13
#       9
#      10     # Add user input to the list of messages
#      11     add_user_message(messages, user_input)
#      12     # Call Claude with the 'chat' function
# ---> 13     answer = chat(messages)
#      14
#      15     # Add Claude's response to the conversation history
#      16     add_assistant_message(messages, answer)
#
# Cell In[3], line 10, in chat(messages)
#       9 def chat(messages):
# ---> 10     message = client.messages.create(
#      11         model=model,
#      12         max_tokens=1000,
#      13         messages=messages,
#
# File ~/Downloads/git-repos/ai-avengers/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Downloads/git-repos/ai-avengers/.venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~/Downloads/git-repos/ai-avengers/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Downloads/git-repos/ai-avengers/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.2: user messages must have non-empty content'}, 'request_id': 'req_011CetJ7vKyt4QsWapAQvUDH'}
